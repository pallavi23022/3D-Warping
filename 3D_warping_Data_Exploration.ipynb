# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavi23022/3D-Warping/blob/main/3D_warping_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://mmlab.ie.cuhk.edu.hk/projects/DeepFashion/InShopRetrieval.html **Import the dataset**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile
file_name= "/content/drive/My Drive/In-shop Clothes Retrieval Benchmark/Img/img.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()

# %%
import cv2
import numpy as np
from glob import glob #used to tranverse, at same location, having specific pattern


men_files = np.array(glob("/content/img/MEN/*/*/*"))
women_files=np.array(glob("/content/img/WOMEN/*/*/*"))

print(len(men_files))
print(len(women_files))
# Out:
# 7838
# 44874

# %%
print(men_files[0])
print(women_files[456])
# Out:
# /content/img/MEN/Tees_Tanks/id_00007234/02_7_additional.jpg
# /content/img/WOMEN/Tees_Tanks/id_00006657/06_3_back.jpg

# %%
men_class=np.array(glob("/content/img/MEN/*"))
print(men_class[0])
# Out:
# /content/img/MEN/Tees_Tanks

# %%
type(men_class[0])
# Out:
# numpy.str_

# %%
men_classes=[]
for i in range(0,len(men_class)):
  men_classes.append(men_class[i].split("/")[-1])
print(len(men_classes))
men_classes
# Out:
# 9
# ['Tees_Tanks',
#  'Sweaters',
#  'Shirts_Polos',
#  'Jackets_Vests',
#  'Shorts',
#  'Denim',
#  'Suiting',
#  'Pants',
#  'Sweatshirts_Hoodies']

# %%
women_class=np.array(glob("/content/img/WOMEN/*"))
print(women_class[0])
# Out:
# /content/img/WOMEN/Tees_Tanks

# %%
women_classes=[]
for j in range(0,len(women_class)):
  women_classes.append(women_class[j].split("/")[-1])
print(len(women_classes))
women_classes
# Out:
# 14
# ['Tees_Tanks',
#  'Sweaters',
#  'Cardigans',
#  'Rompers_Jumpsuits',
#  'Dresses',
#  'Skirts',
#  'Shorts',
#  'Jackets_Coats',
#  'Denim',
#  'Leggings',
#  'Pants',
#  'Graphic_Tees',
#  'Sweatshirts_Hoodies',
#  'Blouses_Shirts']

# %% [markdown]
# ### **Printing the Images**

# %%
m_image=cv2.imread(men_files[0])
w_image=cv2.imread(women_files[0])

from google.colab.patches import cv2_imshow

cv2_imshow(m_image)
cv2_imshow(w_image)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FA54D10D150>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FA54D1DB090>
